# %% [markdown]
# # Backpropagation
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import torch 
x=torch.tensor(1.0)
y=torch.tensor(2.0)

w=torch.tensor(1.0,requires_grad=True)
# forward pass and comput loss
y_hat=w*x
loss=(y_hat-y)**2
print(loss)
# Backward pass
loss.backward()
print(w.grad)
## updated weights
# Out:
# tensor(1., grad_fn=<PowBackward0>)
# tensor(-2.)
